# %% [markdown]
# # [2] CSV to SQL Part 1 - Lending Club Data

# %% [markdown]
# ---
# I have sourced my loan data from Lending Club which is the largest peer-to-peer lending organisation in the world. I downloaded 12 csv files from Lending Club, covering loans from 2007 to 2017. The size of the data is well over 1GB. Therefore, my first steps will be to push the data into an SQL database. This will significantly speed up the process of loading the data into pandas and also allow me to use SQL queries.
#
# Once I have stored my data in SQL, I will then perform exploratory data analysis to clean and analyse the data. Following that, I will create a classification model to classify if a loan will default or be fully paid, with the predicted values being 1 and 0, respectively.
#
# ---

# %%
import pandas as pd

# %%
# Create SQL alchemy engine to create a connection with my local PostgreSQL database.
from sqlalchemy import create_engine
engine = create_engine('postgresql://postgres:database@localhost:5432/Capstone')

# %% [markdown]
# ---
# I have downloaded 12 csv files from Lending Club, covering 10 years worth of data. All columns are the same. I will load each file into pandas and then push it into a local PostgreSQL database, where each file will be used to create a table. The advantage of using SQL is that it will massively increase read times over reading in from csv and also allow the use of SQL queries. Once all 12 files are in SQL, I can concatonate them to form one large table with all records.
#
# ---

# %% [markdown]
# ## 2007-2011

# %% [markdown]
# ---
# The first file covers loans from the years 2007 to 2011. I will load it into pandas before pushing it into SQL.
#
# ---

# %%
file1 = './Datasets/Lending Club/lendclub_07-11.csv'   # Path of file.

# %%
df1 = pd.read_csv(file1, skiprows=1, skipfooter=2)
# Skip first row and last two rows because they are not columns and prevent normal loading into pandas.
# Out:
# /Applications/anaconda2/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.

# %%
df1.head()
# Out:
#     id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  NaN        NaN     5000.0       5000.0           4975.0   36 months
# 1  NaN        NaN     2500.0       2500.0           2500.0   60 months
# 2  NaN        NaN     2400.0       2400.0           2400.0   36 months
# 3  NaN        NaN    10000.0      10000.0          10000.0   36 months
# 4  NaN        NaN     3000.0       3000.0           3000.0   60 months
#
#   int_rate  installment grade sub_grade       ...        \
# 0   10.65%       162.87     B        B2       ...
# 1   15.27%        59.83     C        C4       ...
# 2   15.96%        84.33     C        C5       ...
# 3   13.49%       339.31     C        C1       ...
# 4   12.69%        67.79     B        B5       ...
#
#   hardship_payoff_balance_amount hardship_last_payment_amount  \
# 0                            NaN                          NaN
# 1                            NaN                          NaN
# 2                            NaN                          NaN
# 3                            NaN                          NaN
# 4                            NaN                          NaN
#
#   disbursement_method  debt_settlement_flag debt_settlement_flag_date  \
# 0                Cash                     N                       NaN
# 1                Cash                     N                       NaN
# 2                Cash                     N                       NaN
# 3                Cash                     N                       NaN
# 4                Cash                     N                       NaN
#
#   settlement_status settlement_date settlement_amount  settlement_percentage  \
# 0               NaN             NaN               NaN                    NaN
# 1               NaN             NaN               NaN                    NaN
# 2               NaN             NaN               NaN                    NaN
# 3               NaN             NaN               NaN                    NaN
# 4               NaN             NaN               NaN                    NaN
#
#   settlement_term
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#
# [5 rows x 145 columns]

# %%
df1.tail()
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 42531  NaN        NaN     3500.0       3500.0            225.0   36 months
# 42532  NaN        NaN     1000.0       1000.0              0.0   36 months
# 42533  NaN        NaN     2525.0       2525.0            225.0   36 months
# 42534  NaN        NaN     6500.0       6500.0              0.0   36 months
# 42535  NaN        NaN     5000.0       5000.0              0.0   36 months
#
#       int_rate  installment grade sub_grade       ...        \
# 42531   10.28%       113.39     C        C1       ...
# 42532    9.64%        32.11     B        B4       ...
# 42533    9.33%        80.69     B        B3       ...
# 42534    8.38%       204.84     A        A5       ...
# 42535    7.75%       156.11     A        A3       ...
#
#       hardship_payoff_balance_amount hardship_last_payment_amount  \
# 42531                            NaN                          NaN
# 42532                            NaN                          NaN
# 42533                            NaN                          NaN
# 42534                            NaN                          NaN
# 42535                            NaN                          NaN
#
#       disbursement_method  debt_settlement_flag debt_settlement_flag_date  \
# 42531                Cash                     N                       NaN
# 42532                Cash                     N                       NaN
# 42533                Cash                     N                       NaN
# 42534                Cash                     N                       NaN
# 42535                Cash                     N                       NaN
#
#       settlement_status settlement_date settlement_amount  \
# 42531               NaN             NaN               NaN
# 42532               NaN             NaN               NaN
# 42533               NaN             NaN               NaN
# 42534               NaN             NaN               NaN
# 42535               NaN             NaN               NaN
#
#        settlement_percentage settlement_term
# 42531                    NaN             NaN
# 42532                    NaN             NaN
# 42533                    NaN             NaN
# 42534                    NaN             NaN
# 42535                    NaN             NaN
#
# [5 rows x 145 columns]

# %%
df1.shape
# Out:
# (42536, 145)

# %%
df1.to_sql(name='LC_07-11', con=engine, if_exists='replace', index = False)

# %% [markdown]
# ---
# Push the dataframe into an SQL table and then query it to make sure it has worked.
#
# ---

# %%
SQL_STRING = '''

select * from "LC_07-11"
'''

df = pd.read_sql(SQL_STRING, con=engine)
df.head()
# Out:
#      id member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  None      None     5000.0       5000.0           4975.0   36 months
# 1  None      None     2500.0       2500.0           2500.0   60 months
# 2  None      None     2400.0       2400.0           2400.0   36 months
# 3  None      None    10000.0      10000.0          10000.0   36 months
# 4  None      None     3000.0       3000.0           3000.0   60 months
#
#   int_rate  installment grade sub_grade       ...        \
# 0   10.65%       162.87     B        B2       ...
# 1   15.27%        59.83     C        C4       ...
# 2   15.96%        84.33     C        C5       ...
# 3   13.49%       339.31     C        C1       ...
# 4   12.69%        67.79     B        B5       ...
#
#   hardship_payoff_balance_amount hardship_last_payment_amount  \
# 0                           None                         None
# 1                           None                         None
# 2                           None                         None
# 3                           None                         None
# 4                           None                         None
#
#   disbursement_method  debt_settlement_flag debt_settlement_flag_date  \
# 0                Cash                     N                      None
# 1                Cash                     N                      None
# 2                Cash                     N                      None
# 3                Cash                     N                      None
# 4                Cash                     N                      None
#
#   settlement_status settlement_date settlement_amount settlement_percentage  \
# 0              None            None               NaN                   NaN
# 1              None            None               NaN                   NaN
# 2              None            None               NaN                   NaN
# 3              None            None               NaN                   NaN
# 4              None            None               NaN                   NaN
#
#   settlement_term
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#
# [5 rows x 145 columns]

# %%
df.shape
# Out:
# (42536, 145)

# %% [markdown]
# ## 2012-2013

# %% [markdown]
# ---
# Now I will repeat this process for the other 11 files.
#
# ---

# %%
file2 = './Datasets/Lending Club/lendclub_12-13.csv'

# %%
df2 = pd.read_csv(file2, skiprows=1, skipfooter=2)
# Out:
# /Applications/anaconda2/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.

# %%
df2.head()
# Out:
#    id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0 NaN        NaN      14000        14000          14000.0   36 months
# 1 NaN        NaN      15000        15000          15000.0   36 months
# 2 NaN        NaN      15000        15000          15000.0   36 months
# 3 NaN        NaN      10000        10000          10000.0   36 months
# 4 NaN        NaN      20800        20800          20800.0   36 months
#
#   int_rate  installment grade sub_grade       ...        \
# 0   12.85%       470.71     B        B4       ...
# 1   14.47%       516.10     C        C2       ...
# 2    8.90%       476.30     A        A5       ...
# 3    9.67%       321.13     B        B1       ...
# 4   13.53%       706.16     B        B5       ...
#
#   hardship_payoff_balance_amount hardship_last_payment_amount  \
# 0                            NaN                          NaN
# 1                            NaN                          NaN
# 2                            NaN                          NaN
# 3                            NaN                          NaN
# 4                            NaN                          NaN
#
#   disbursement_method  debt_settlement_flag debt_settlement_flag_date  \
# 0                Cash                     N                       NaN
# 1                Cash                     N                       NaN
# 2                Cash                     N                       NaN
# 3                Cash                     N                       NaN
# 4                Cash                     N                       NaN
#
#   settlement_status settlement_date settlement_amount  settlement_percentage  \
# 0               NaN             NaN               NaN                    NaN
# 1               NaN             NaN               NaN                    NaN
# 2               NaN             NaN               NaN                    NaN
# 3               NaN             NaN               NaN                    NaN
# 4               NaN             NaN               NaN                    NaN
#
#   settlement_term
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#
# [5 rows x 145 columns]

# %%
df2.tail()
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 188176 NaN        NaN      20500        20500          20500.0   36 months
# 188177 NaN        NaN      15000        15000          15000.0   36 months
# 188178 NaN        NaN      35000        35000          35000.0   36 months
# 188179 NaN        NaN      12000        12000          12000.0   36 months
# 188180 NaN        NaN      12000         7775           7775.0   60 months
#
#        int_rate  installment grade sub_grade       ...        \
# 188176   16.77%       728.54     D        D2       ...
# 188177   15.27%       521.97     C        C4       ...
# 188178   15.96%      1229.81     C        C5       ...
# 188179   16.29%       423.61     D        D1       ...
# 188180   15.27%       186.08     C        C4       ...
#
#        hardship_payoff_balance_amount hardship_last_payment_amount  \
# 188176                            NaN                          NaN
# 188177                            NaN                          NaN
# 188178                            NaN                          NaN
# 188179                            NaN                          NaN
# 188180                            NaN                          NaN
#
#        disbursement_method  debt_settlement_flag debt_settlement_flag_date  \
# 188176                Cash                     N                       NaN
# 188177                Cash                     N                       NaN
# 188178                Cash                     N                       NaN
# 188179                Cash                     N                       NaN
# 188180                Cash                     N                       NaN
#
#        settlement_status settlement_date settlement_amount  \
# 188176               NaN             NaN               NaN
# 188177               NaN             NaN               NaN
# 188178               NaN             NaN               NaN
# 188179               NaN             NaN               NaN
# 188180               NaN             NaN               NaN
#
#         settlement_percentage settlement_term
# 188176                    NaN             NaN
# 188177                    NaN             NaN
# 188178                    NaN             NaN
# 188179                    NaN             NaN
# 188180                    NaN             NaN
#
# [5 rows x 145 columns]

# %%
df2.shape
# Out:
# (188181, 145)

# %%
df2.to_sql(name='LC_12-13', con=engine, if_exists='replace', index = False)

# %%
SQL_STRING = '''

select * from "LC_12-13"
'''

df = pd.read_sql(SQL_STRING, con=engine)
df.head()
# Out:
#      id member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  None      None      14000        14000          14000.0   36 months
# 1  None      None      15000        15000          15000.0   36 months
# 2  None      None      15000        15000          15000.0   36 months
# 3  None      None      10000        10000          10000.0   36 months
# 4  None      None      20800        20800          20800.0   36 months
#
#   int_rate  installment grade sub_grade       ...        \
# 0   12.85%       470.71     B        B4       ...
# 1   14.47%       516.10     C        C2       ...
# 2    8.90%       476.30     A        A5       ...
# 3    9.67%       321.13     B        B1       ...
# 4   13.53%       706.16     B        B5       ...
#
#   hardship_payoff_balance_amount hardship_last_payment_amount  \
# 0                            NaN                          NaN
# 1                            NaN                          NaN
# 2                            NaN                          NaN
# 3                            NaN                          NaN
# 4                            NaN                          NaN
#
#   disbursement_method  debt_settlement_flag debt_settlement_flag_date  \
# 0                Cash                     N                      None
# 1                Cash                     N                      None
# 2                Cash                     N                      None
# 3                Cash                     N                      None
# 4                Cash                     N                      None
#
#   settlement_status settlement_date settlement_amount settlement_percentage  \
# 0              None            None               NaN                   NaN
# 1              None            None               NaN                   NaN
# 2              None            None               NaN                   NaN
# 3              None            None               NaN                   NaN
# 4              None            None               NaN                   NaN
#
#   settlement_term
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#
# [5 rows x 145 columns]

# %%
df.shape
# Out:
# (188181, 145)

# %% [markdown]
# ## 2014

# %%
file3 = './Datasets/Lending Club/lendclub_14.csv'

# %%
df3 = pd.read_csv(file3, skiprows=1, skipfooter=2)
# Out:
# /Applications/anaconda2/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.

# %%
df3.head()
# Out:
#    id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0 NaN        NaN      15000        15000            15000   60 months
# 1 NaN        NaN      10400        10400            10400   36 months
# 2 NaN        NaN      12800        12800            12800   60 months
# 3 NaN        NaN       7650         7650             7650   36 months
# 4 NaN        NaN      21425        21425            21425   60 months
#
#   int_rate  installment grade sub_grade       ...        \
# 0   12.39%       336.64     C        C1       ...
# 1    6.99%       321.08     A        A3       ...
# 2   17.14%       319.08     D        D4       ...
# 3   13.66%       260.20     C        C3       ...
# 4   15.59%       516.36     D        D1       ...
#
#   hardship_payoff_balance_amount hardship_last_payment_amount  \
# 0                            NaN                          NaN
# 1                            NaN                          NaN
# 2                            NaN                          NaN
# 3                            NaN                          NaN
# 4                            NaN                          NaN
#
#   disbursement_method  debt_settlement_flag debt_settlement_flag_date  \
# 0                Cash                     N                       NaN
# 1                Cash                     N                       NaN
# 2                Cash                     N                       NaN
# 3                Cash                     N                       NaN
# 4                Cash                     N                       NaN
#
#   settlement_status settlement_date settlement_amount  settlement_percentage  \
# 0               NaN             NaN               NaN                    NaN
# 1               NaN             NaN               NaN                    NaN
# 2               NaN             NaN               NaN                    NaN
# 3               NaN             NaN               NaN                    NaN
# 4               NaN             NaN               NaN                    NaN
#
#   settlement_term
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#
# [5 rows x 145 columns]

# %%
df3.tail()
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 235624 NaN        NaN      18400        18400            18400   60 months
# 235625 NaN        NaN      22000        22000            22000   60 months
# 235626 NaN        NaN      20700        20700            20700   60 months
# 235627 NaN        NaN       2000         2000             2000   36 months
# 235628 NaN        NaN      10000        10000             9975   36 months
#
#        int_rate  installment grade sub_grade       ...        \
# 235624   14.47%       432.64     C        C2       ...
# 235625   19.97%       582.50     D        D5       ...
# 235626   16.99%       514.34     D        D1       ...
# 235627    7.90%        62.59     A        A4       ...
# 235628   19.20%       367.58     D        D3       ...
#
#        hardship_payoff_balance_amount hardship_last_payment_amount  \
# 235624                            NaN                          NaN
# 235625                            NaN                          NaN
# 235626                            NaN                          NaN
# 235627                            NaN                          NaN
# 235628                            NaN                          NaN
#
#        disbursement_method  debt_settlement_flag debt_settlement_flag_date  \
# 235624                Cash                     N                       NaN
# 235625                Cash                     N                       NaN
# 235626                Cash                     N                       NaN
# 235627                Cash                     N                       NaN
# 235628                Cash                     N                       NaN
#
#        settlement_status settlement_date settlement_amount  \
# 235624               NaN             NaN               NaN
# 235625               NaN             NaN               NaN
# 235626               NaN             NaN               NaN
# 235627               NaN             NaN               NaN
# 235628               NaN             NaN               NaN
#
#         settlement_percentage settlement_term
# 235624                    NaN             NaN
# 235625                    NaN             NaN
# 235626                    NaN             NaN
# 235627                    NaN             NaN
# 235628                    NaN             NaN
#
# [5 rows x 145 columns]

# %%
df3.shape
# Out:
# (235629, 145)

# %%
df3.to_sql(name='LC_14', con=engine, if_exists='replace', index = False)

# %%
SQL_STRING = '''

select * from "LC_14"
'''

df = pd.read_sql(SQL_STRING, con=engine)
df.head()
# Out:
#      id member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  None      None      15000        15000            15000   60 months
# 1  None      None      10400        10400            10400   36 months
# 2  None      None      12800        12800            12800   60 months
# 3  None      None       7650         7650             7650   36 months
# 4  None      None      21425        21425            21425   60 months
#
#   int_rate  installment grade sub_grade       ...        \
# 0   12.39%       336.64     C        C1       ...
# 1    6.99%       321.08     A        A3       ...
# 2   17.14%       319.08     D        D4       ...
# 3   13.66%       260.20     C        C3       ...
# 4   15.59%       516.36     D        D1       ...
#
#   hardship_payoff_balance_amount hardship_last_payment_amount  \
# 0                            NaN                          NaN
# 1                            NaN                          NaN
# 2                            NaN                          NaN
# 3                            NaN                          NaN
# 4                            NaN                          NaN
#
#   disbursement_method  debt_settlement_flag debt_settlement_flag_date  \
# 0                Cash                     N                      None
# 1                Cash                     N                      None
# 2                Cash                     N                      None
# 3                Cash                     N                      None
# 4                Cash                     N                      None
#
#   settlement_status settlement_date settlement_amount settlement_percentage  \
# 0              None            None               NaN                   NaN
# 1              None            None               NaN                   NaN
# 2              None            None               NaN                   NaN
# 3              None            None               NaN                   NaN
# 4              None            None               NaN                   NaN
#
#   settlement_term
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#
# [5 rows x 145 columns]

# %%
df.shape
# Out:
# (235629, 145)

# %% [markdown]
# ## 2015

# %%
file4 = './Datasets/Lending Club/lendclub_15.csv'

# %%
df4 = pd.read_csv(file4, skiprows=1, skipfooter=2)
# Out:
# /Applications/anaconda2/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.

# %%
df4.head()
# Out:
#    id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0 NaN        NaN       9000         9000           9000.0   36 months
# 1 NaN        NaN      17475        17475          17475.0   36 months
# 2 NaN        NaN      21000        21000          21000.0   60 months
# 3 NaN        NaN       7200         7200           7200.0   36 months
# 4 NaN        NaN      27500        27500          27500.0   60 months
#
#   int_rate  installment grade sub_grade       ...        \
# 0    8.49%       284.07     B        B1       ...
# 1   13.99%       597.17     C        C4       ...
# 2   13.99%       488.53     C        C4       ...
# 3   11.48%       237.36     B        B5       ...
# 4   14.85%       652.06     C        C5       ...
#
#   hardship_payoff_balance_amount hardship_last_payment_amount  \
# 0                            NaN                          NaN
# 1                            NaN                          NaN
# 2                            NaN                          NaN
# 3                            NaN                          NaN
# 4                            NaN                          NaN
#
#   disbursement_method  debt_settlement_flag debt_settlement_flag_date  \
# 0                Cash                     N                       NaN
# 1                Cash                     Y                  Jan-2018
# 2                Cash                     N                       NaN
# 3                Cash                     N                       NaN
# 4                Cash                     N                       NaN
#
#   settlement_status settlement_date settlement_amount  settlement_percentage  \
# 0               NaN             NaN               NaN                    NaN
# 1            ACTIVE        Jan-2018            4382.0                  44.99
# 2               NaN             NaN               NaN                    NaN
# 3               NaN             NaN               NaN                    NaN
# 4               NaN             NaN               NaN                    NaN
#
#   settlement_term
# 0             NaN
# 1            12.0
# 2             NaN
# 3             NaN
# 4             NaN
#
# [5 rows x 145 columns]

# %%
df4.tail()
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 421090 NaN        NaN      10000        10000          10000.0   36 months
# 421091 NaN        NaN      24000        24000          24000.0   36 months
# 421092 NaN        NaN      12000        12000          12000.0   60 months
# 421093 NaN        NaN      13000        13000          13000.0   60 months
# 421094 NaN        NaN      20000        20000          20000.0   36 months
#
#        int_rate  installment grade sub_grade       ...        \
# 421090   11.99%       332.10     B        B5       ...
# 421091   11.99%       797.03     B        B5       ...
# 421092   19.99%       317.86     E        E3       ...
# 421093   15.99%       316.07     D        D2       ...
# 421094   11.99%       664.20     B        B5       ...
#
#        hardship_payoff_balance_amount hardship_last_payment_amount  \
# 421090                            NaN                          NaN
# 421091                            NaN                          NaN
# 421092                            NaN                          NaN
# 421093                            NaN                          NaN
# 421094                            NaN                          NaN
#
#        disbursement_method  debt_settlement_flag debt_settlement_flag_date  \
# 421090                Cash                     N                       NaN
# 421091                Cash                     N                       NaN
# 421092                Cash                     N                       NaN
# 421093                Cash                     N                       NaN
# 421094                Cash                     N                       NaN
#
#        settlement_status settlement_date settlement_amount  \
# 421090               NaN             NaN               NaN
# 421091               NaN             NaN               NaN
# 421092               NaN             NaN               NaN
# 421093               NaN             NaN               NaN
# 421094               NaN             NaN               NaN
#
#         settlement_percentage settlement_term
# 421090                    NaN             NaN
# 421091                    NaN             NaN
# 421092                    NaN             NaN
# 421093                    NaN             NaN
# 421094                    NaN             NaN
#
# [5 rows x 145 columns]

# %%
df4.shape
# Out:
# (421095, 145)

# %%
df4.to_sql(name='LC_15', con=engine, if_exists='replace', index = False)

# %%
SQL_STRING = '''

select * from "LC_15"
'''

df = pd.read_sql(SQL_STRING, con=engine)
df.head()
# Out:
#      id member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  None      None       9000         9000           9000.0   36 months
# 1  None      None      17475        17475          17475.0   36 months
# 2  None      None      21000        21000          21000.0   60 months
# 3  None      None       7200         7200           7200.0   36 months
# 4  None      None      27500        27500          27500.0   60 months
#
#   int_rate  installment grade sub_grade       ...        \
# 0    8.49%       284.07     B        B1       ...
# 1   13.99%       597.17     C        C4       ...
# 2   13.99%       488.53     C        C4       ...
# 3   11.48%       237.36     B        B5       ...
# 4   14.85%       652.06     C        C5       ...
#
#   hardship_payoff_balance_amount hardship_last_payment_amount  \
# 0                            NaN                          NaN
# 1                            NaN                          NaN
# 2                            NaN                          NaN
# 3                            NaN                          NaN
# 4                            NaN                          NaN
#
#   disbursement_method  debt_settlement_flag debt_settlement_flag_date  \
# 0                Cash                     N                      None
# 1                Cash                     Y                  Jan-2018
# 2                Cash                     N                      None
# 3                Cash                     N                      None
# 4                Cash                     N                      None
#
#   settlement_status settlement_date settlement_amount settlement_percentage  \
# 0              None            None               NaN                   NaN
# 1            ACTIVE        Jan-2018            4382.0                 44.99
# 2              None            None               NaN                   NaN
# 3              None            None               NaN                   NaN
# 4              None            None               NaN                   NaN
#
#   settlement_term
# 0             NaN
# 1            12.0
# 2             NaN
# 3             NaN
# 4             NaN
#
# [5 rows x 145 columns]

# %%
df.shape
# Out:
# (421095, 145)

# %% [markdown]
# ## 2016 Q1

# %%
file5 = './Datasets/Lending Club/lendclub_16-q1.csv'

# %%
df5 = pd.read_csv(file5, skiprows=1, skipfooter=2)
# Out:
# /Applications/anaconda2/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.

# %%
df5.head()
# Out:
#    id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0 NaN        NaN      10000        10000          10000.0   60 months
# 1 NaN        NaN      35000        35000          35000.0   60 months
# 2 NaN        NaN      20000        20000          20000.0   60 months
# 3 NaN        NaN      17475        17475          17475.0   60 months
# 4 NaN        NaN       8000         8000           8000.0   36 months
#
#   int_rate  installment grade sub_grade       ...        \
# 0   19.53%       262.34     D        D5       ...
# 1   20.75%       941.96     E        E2       ...
# 2    9.16%       416.73     B        B2       ...
# 3   11.47%       384.06     B        B5       ...
# 4    9.16%       255.00     B        B2       ...
#
#   hardship_payoff_balance_amount hardship_last_payment_amount  \
# 0                            NaN                          NaN
# 1                            NaN                          NaN
# 2                            NaN                          NaN
# 3                            NaN                          NaN
# 4                            NaN                          NaN
#
#   disbursement_method  debt_settlement_flag debt_settlement_flag_date  \
# 0                Cash                     N                       NaN
# 1                Cash                     N                       NaN
# 2                Cash                     N                       NaN
# 3                Cash                     N                       NaN
# 4                Cash                     N                       NaN
#
#   settlement_status settlement_date settlement_amount  settlement_percentage  \
# 0               NaN             NaN               NaN                    NaN
# 1               NaN             NaN               NaN                    NaN
# 2               NaN             NaN               NaN                    NaN
# 3               NaN             NaN               NaN                    NaN
# 4               NaN             NaN               NaN                    NaN
#
#   settlement_term
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#
# [5 rows x 145 columns]

# %%
df5.tail()
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 133882 NaN        NaN       6000         6000           6000.0   36 months
# 133883 NaN        NaN       6000         6000           6000.0   36 months
# 133884 NaN        NaN      14400        14400          14400.0   60 months
# 133885 NaN        NaN      34050        34050          34050.0   36 months
# 133886 NaN        NaN       5000         5000           5000.0   36 months
#
#        int_rate  installment grade sub_grade       ...        \
# 133882    7.89%       187.72     A        A5       ...
# 133883    9.17%       191.28     B        B2       ...
# 133884   13.18%       328.98     C        C3       ...
# 133885   15.41%      1187.21     D        D1       ...
# 133886   11.22%       164.22     B        B5       ...
#
#        hardship_payoff_balance_amount hardship_last_payment_amount  \
# 133882                            NaN                          NaN
# 133883                            NaN                          NaN
# 133884                            NaN                          NaN
# 133885                            NaN                          NaN
# 133886                            NaN                          NaN
#
#        disbursement_method  debt_settlement_flag debt_settlement_flag_date  \
# 133882                Cash                     N                       NaN
# 133883                Cash                     N                       NaN
# 133884                Cash                     N                       NaN
# 133885                Cash                     N                       NaN
# 133886                Cash                     N                       NaN
#
#        settlement_status settlement_date settlement_amount  \
# 133882               NaN             NaN               NaN
# 133883               NaN             NaN               NaN
# 133884               NaN             NaN               NaN
# 133885               NaN             NaN               NaN
# 133886               NaN             NaN               NaN
#
#         settlement_percentage settlement_term
# 133882                    NaN             NaN
# 133883                    NaN             NaN
# 133884                    NaN             NaN
# 133885                    NaN             NaN
# 133886                    NaN             NaN
#
# [5 rows x 145 columns]

# %%
df5.shape
# Out:
# (133887, 145)

# %%
df5.to_sql(name='LC_16-q1', con=engine, if_exists='replace', index = False)

# %%
SQL_STRING = '''

select * from "LC_16-q1"
'''

df = pd.read_sql(SQL_STRING, con=engine)
df.head()
# Out:
#      id member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  None      None      10000        10000          10000.0   60 months
# 1  None      None      35000        35000          35000.0   60 months
# 2  None      None      20000        20000          20000.0   60 months
# 3  None      None      17475        17475          17475.0   60 months
# 4  None      None       8000         8000           8000.0   36 months
#
#   int_rate  installment grade sub_grade       ...        \
# 0   19.53%       262.34     D        D5       ...
# 1   20.75%       941.96     E        E2       ...
# 2    9.16%       416.73     B        B2       ...
# 3   11.47%       384.06     B        B5       ...
# 4    9.16%       255.00     B        B2       ...
#
#   hardship_payoff_balance_amount hardship_last_payment_amount  \
# 0                            NaN                          NaN
# 1                            NaN                          NaN
# 2                            NaN                          NaN
# 3                            NaN                          NaN
# 4                            NaN                          NaN
#
#   disbursement_method  debt_settlement_flag debt_settlement_flag_date  \
# 0                Cash                     N                      None
# 1                Cash                     N                      None
# 2                Cash                     N                      None
# 3                Cash                     N                      None
# 4                Cash                     N                      None
#
#   settlement_status settlement_date settlement_amount settlement_percentage  \
# 0              None            None               NaN                   NaN
# 1              None            None               NaN                   NaN
# 2              None            None               NaN                   NaN
# 3              None            None               NaN                   NaN
# 4              None            None               NaN                   NaN
#
#   settlement_term
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#
# [5 rows x 145 columns]

# %%
df.shape
# Out:
# (133887, 145)

# %% [markdown]
# ## 2016 Q2

# %%
file6 = './Datasets/Lending Club/lendclub_16-q2.csv'

# %%
df6 = pd.read_csv(file6, skiprows=1, skipfooter=2)
# Out:
# /Applications/anaconda2/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.

# %%
df6.head()
# Out:
#    id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0 NaN        NaN      24000        24000          24000.0   60 months
# 1 NaN        NaN      16000        16000          16000.0   60 months
# 2 NaN        NaN      12000        12000          12000.0   60 months
# 3 NaN        NaN       7500         7500           7500.0   36 months
# 4 NaN        NaN      21000        21000          21000.0   36 months
#
#   int_rate  installment grade sub_grade       ...        \
# 0   13.99%       558.32     C        C3       ...
# 1   15.59%       385.62     C        C5       ...
# 2   21.49%       327.96     D        D5       ...
# 3   10.99%       245.51     B        B4       ...
# 4   13.49%       712.54     C        C2       ...
#
#   hardship_payoff_balance_amount hardship_last_payment_amount  \
# 0                            NaN                          NaN
# 1                            NaN                          NaN
# 2                            NaN                          NaN
# 3                            NaN                          NaN
# 4                            NaN                          NaN
#
#   disbursement_method  debt_settlement_flag debt_settlement_flag_date  \
# 0                Cash                     N                       NaN
# 1                Cash                     N                       NaN
# 2                Cash                     N                       NaN
# 3                Cash                     N                       NaN
# 4                Cash                     N                       NaN
#
#   settlement_status settlement_date settlement_amount  settlement_percentage  \
# 0               NaN             NaN               NaN                    NaN
# 1               NaN             NaN               NaN                    NaN
# 2               NaN             NaN               NaN                    NaN
# 3               NaN             NaN               NaN                    NaN
# 4               NaN             NaN               NaN                    NaN
#
#   settlement_term
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#
# [5 rows x 145 columns]

# %%
df6.tail()
# Out:
#        id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 97849 NaN        NaN       7000         7000           7000.0   36 months
# 97850 NaN        NaN      21475        21475          21475.0   60 months
# 97851 NaN        NaN       6050         6050           6050.0   60 months
# 97852 NaN        NaN      30000        30000          30000.0   60 months
# 97853 NaN        NaN       5000         5000           5000.0   36 months
#
#       int_rate  installment grade sub_grade       ...        \
# 97849    5.32%       210.81     A        A1       ...
# 97850   17.27%       536.84     D        D2       ...
# 97851   18.25%       154.46     D        D3       ...
# 97852   18.99%       778.06     D        D4       ...
# 97853   10.75%       163.11     B        B4       ...
#
#       hardship_payoff_balance_amount hardship_last_payment_amount  \
# 97849                            NaN                          NaN
# 97850                            NaN                          NaN
# 97851                            NaN                          NaN
# 97852                            NaN                          NaN
# 97853                            NaN                          NaN
#
#       disbursement_method  debt_settlement_flag debt_settlement_flag_date  \
# 97849                Cash                     N                       NaN
# 97850                Cash                     N                       NaN
# 97851                Cash                     N                       NaN
# 97852                Cash                     N                       NaN
# 97853                Cash                     N                       NaN
#
#       settlement_status settlement_date settlement_amount  \
# 97849               NaN             NaN               NaN
# 97850               NaN             NaN               NaN
# 97851               NaN             NaN               NaN
# 97852               NaN             NaN               NaN
# 97853               NaN             NaN               NaN
#
#        settlement_percentage settlement_term
# 97849                    NaN             NaN
# 97850                    NaN             NaN
# 97851                    NaN             NaN
# 97852                    NaN             NaN
# 97853                    NaN             NaN
#
# [5 rows x 145 columns]

# %%
df6.shape
# Out:
# (97854, 145)

# %%
df6.to_sql(name='LC_16-q2', con=engine, if_exists='replace', index = False)

# %%
SQL_STRING = '''

select * from "LC_16-q2"
'''

df = pd.read_sql(SQL_STRING, con=engine)
df.head()
# Out:
#      id member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  None      None      24000        24000          24000.0   60 months
# 1  None      None      16000        16000          16000.0   60 months
# 2  None      None      12000        12000          12000.0   60 months
# 3  None      None       7500         7500           7500.0   36 months
# 4  None      None      21000        21000          21000.0   36 months
#
#   int_rate  installment grade sub_grade       ...        \
# 0   13.99%       558.32     C        C3       ...
# 1   15.59%       385.62     C        C5       ...
# 2   21.49%       327.96     D        D5       ...
# 3   10.99%       245.51     B        B4       ...
# 4   13.49%       712.54     C        C2       ...
#
#   hardship_payoff_balance_amount hardship_last_payment_amount  \
# 0                            NaN                          NaN
# 1                            NaN                          NaN
# 2                            NaN                          NaN
# 3                            NaN                          NaN
# 4                            NaN                          NaN
#
#   disbursement_method  debt_settlement_flag debt_settlement_flag_date  \
# 0                Cash                     N                      None
# 1                Cash                     N                      None
# 2                Cash                     N                      None
# 3                Cash                     N                      None
# 4                Cash                     N                      None
#
#   settlement_status settlement_date settlement_amount settlement_percentage  \
# 0              None            None               NaN                   NaN
# 1              None            None               NaN                   NaN
# 2              None            None               NaN                   NaN
# 3              None            None               NaN                   NaN
# 4              None            None               NaN                   NaN
#
#   settlement_term
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#
# [5 rows x 145 columns]

# %%
df.shape
# Out:
# (97854, 145)

# %% [markdown]
# ## 2016 Q3

# %%
file7 = './Datasets/Lending Club/lendclub_16-q3.csv'

# %%
df7 = pd.read_csv(file7, skiprows=1, skipfooter=2)
# Out:
# /Applications/anaconda2/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.

# %%
df7.head()
# Out:
#    id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0 NaN        NaN      15000        15000            15000   36 months
# 1 NaN        NaN      14000        14000            14000   36 months
# 2 NaN        NaN       7000         7000             7000   36 months
# 3 NaN        NaN       4200         4200             4200   36 months
# 4 NaN        NaN      18000        18000            18000   36 months
#
#   int_rate  installment grade sub_grade       ...        \
# 0   13.99%       512.60     C        C3       ...
# 1   14.49%       481.83     C        C4       ...
# 2    7.59%       218.04     A        A3       ...
# 3    8.59%       132.76     A        A5       ...
# 4    8.59%       568.97     A        A5       ...
#
#   hardship_payoff_balance_amount hardship_last_payment_amount  \
# 0                            NaN                          NaN
# 1                            NaN                          NaN
# 2                            NaN                          NaN
# 3                            NaN                          NaN
# 4                            NaN                          NaN
#
#   disbursement_method  debt_settlement_flag debt_settlement_flag_date  \
# 0                Cash                     N                       NaN
# 1                Cash                     N                       NaN
# 2                Cash                     N                       NaN
# 3                Cash                     N                       NaN
# 4                Cash                     N                       NaN
#
#   settlement_status settlement_date settlement_amount  settlement_percentage  \
# 0               NaN             NaN               NaN                    NaN
# 1               NaN             NaN               NaN                    NaN
# 2               NaN             NaN               NaN                    NaN
# 3               NaN             NaN               NaN                    NaN
# 4               NaN             NaN               NaN                    NaN
#
#   settlement_term
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#
# [5 rows x 145 columns]

# %%
df7.tail()
# Out:
#        id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 99115 NaN        NaN       2100         2100             2100   36 months
# 99116 NaN        NaN       5000         5000             5000   36 months
# 99117 NaN        NaN      32000        32000            32000   60 months
# 99118 NaN        NaN       1600         1600             1600   36 months
# 99119 NaN        NaN      34000        34000            34000   60 months
#
#       int_rate  installment grade sub_grade       ...        \
# 99115   10.75%        68.51     B        B4       ...
# 99116    7.39%       155.28     A        A4       ...
# 99117   10.49%       687.65     B        B3       ...
# 99118   14.49%        55.07     C        C4       ...
# 99119    7.89%       687.61     A        A5       ...
#
#       hardship_payoff_balance_amount hardship_last_payment_amount  \
# 99115                            NaN                          NaN
# 99116                            NaN                          NaN
# 99117                            NaN                          NaN
# 99118                            NaN                          NaN
# 99119                            NaN                          NaN
#
#       disbursement_method  debt_settlement_flag debt_settlement_flag_date  \
# 99115                Cash                     N                       NaN
# 99116                Cash                     N                       NaN
# 99117                Cash                     N                       NaN
# 99118                Cash                     N                       NaN
# 99119                Cash                     N                       NaN
#
#       settlement_status settlement_date settlement_amount  \
# 99115               NaN             NaN               NaN
# 99116               NaN             NaN               NaN
# 99117               NaN             NaN               NaN
# 99118               NaN             NaN               NaN
# 99119               NaN             NaN               NaN
#
#        settlement_percentage settlement_term
# 99115                    NaN             NaN
# 99116                    NaN             NaN
# 99117                    NaN             NaN
# 99118                    NaN             NaN
# 99119                    NaN             NaN
#
# [5 rows x 145 columns]

# %%
df7.shape
# Out:
# (99120, 145)

# %%
df7.to_sql(name='LC_16-q3', con=engine, if_exists='replace', index = False)

# %%
SQL_STRING = '''

select * from "LC_16-q3"
'''

df = pd.read_sql(SQL_STRING, con=engine)
df.head()
# Out:
#      id member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  None      None      15000        15000            15000   36 months
# 1  None      None      14000        14000            14000   36 months
# 2  None      None       7000         7000             7000   36 months
# 3  None      None       4200         4200             4200   36 months
# 4  None      None      18000        18000            18000   36 months
#
#   int_rate  installment grade sub_grade       ...        \
# 0   13.99%       512.60     C        C3       ...
# 1   14.49%       481.83     C        C4       ...
# 2    7.59%       218.04     A        A3       ...
# 3    8.59%       132.76     A        A5       ...
# 4    8.59%       568.97     A        A5       ...
#
#   hardship_payoff_balance_amount hardship_last_payment_amount  \
# 0                            NaN                          NaN
# 1                            NaN                          NaN
# 2                            NaN                          NaN
# 3                            NaN                          NaN
# 4                            NaN                          NaN
#
#   disbursement_method  debt_settlement_flag debt_settlement_flag_date  \
# 0                Cash                     N                      None
# 1                Cash                     N                      None
# 2                Cash                     N                      None
# 3                Cash                     N                      None
# 4                Cash                     N                      None
#
#   settlement_status settlement_date settlement_amount settlement_percentage  \
# 0              None            None               NaN                   NaN
# 1              None            None               NaN                   NaN
# 2              None            None               NaN                   NaN
# 3              None            None               NaN                   NaN
# 4              None            None               NaN                   NaN
#
#   settlement_term
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#
# [5 rows x 145 columns]

# %%
df.shape
# Out:
# (99120, 145)

# %% [markdown]
# ## 2016 Q4

# %%
file8 = './Datasets/Lending Club/lendclub_16-q4.csv'

# %%
df8 = pd.read_csv(file8, skiprows=1, skipfooter=2)
# Out:
# /Applications/anaconda2/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.

# %%
df8.head()
# Out:
#    id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0 NaN        NaN      19200        19200          19200.0   36 months
# 1 NaN        NaN      11100        11100          11100.0   36 months
# 2 NaN        NaN       8000         8000           8000.0   36 months
# 3 NaN        NaN      39000        39000          39000.0   36 months
# 4 NaN        NaN      13400        13400          13400.0   36 months
#
#   int_rate  installment grade sub_grade       ...        \
# 0   13.99%       656.12     C        C3       ...
# 1    5.32%       334.28     A        A1       ...
# 2    7.99%       250.66     A        A5       ...
# 3   15.99%      1370.94     C        C5       ...
# 4   13.49%       454.67     C        C2       ...
#
#   hardship_payoff_balance_amount hardship_last_payment_amount  \
# 0                            NaN                          NaN
# 1                            NaN                          NaN
# 2                            NaN                          NaN
# 3                            NaN                          NaN
# 4                            NaN                          NaN
#
#   disbursement_method  debt_settlement_flag debt_settlement_flag_date  \
# 0                Cash                     N                       NaN
# 1                Cash                     N                       NaN
# 2                Cash                     N                       NaN
# 3                Cash                     N                       NaN
# 4                Cash                     N                       NaN
#
#   settlement_status settlement_date settlement_amount  settlement_percentage  \
# 0               NaN             NaN               NaN                    NaN
# 1               NaN             NaN               NaN                    NaN
# 2               NaN             NaN               NaN                    NaN
# 3               NaN             NaN               NaN                    NaN
# 4               NaN             NaN               NaN                    NaN
#
#   settlement_term
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#
# [5 rows x 145 columns]

# %%
df8.tail()
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 103541 NaN        NaN      24000        24000          24000.0   60 months
# 103542 NaN        NaN      24000        24000          24000.0   60 months
# 103543 NaN        NaN      40000        40000          40000.0   60 months
# 103544 NaN        NaN      24000        24000          24000.0   60 months
# 103545 NaN        NaN      14000        14000          14000.0   60 months
#
#        int_rate  installment grade sub_grade       ...        \
# 103541   12.79%       543.50     C        C1       ...
# 103542   10.49%       515.74     B        B3       ...
# 103543   10.49%       859.56     B        B3       ...
# 103544   14.49%       564.56     C        C4       ...
# 103545   14.49%       329.33     C        C4       ...
#
#        hardship_payoff_balance_amount hardship_last_payment_amount  \
# 103541                            NaN                          NaN
# 103542                            NaN                          NaN
# 103543                            NaN                          NaN
# 103544                            NaN                          NaN
# 103545                            NaN                          NaN
#
#        disbursement_method  debt_settlement_flag debt_settlement_flag_date  \
# 103541                Cash                     N                       NaN
# 103542                Cash                     N                       NaN
# 103543                Cash                     N                       NaN
# 103544                Cash                     N                       NaN
# 103545                Cash                     N                       NaN
#
#        settlement_status settlement_date settlement_amount  \
# 103541               NaN             NaN               NaN
# 103542               NaN             NaN               NaN
# 103543               NaN             NaN               NaN
# 103544               NaN             NaN               NaN
# 103545               NaN             NaN               NaN
#
#         settlement_percentage settlement_term
# 103541                    NaN             NaN
# 103542                    NaN             NaN
# 103543                    NaN             NaN
# 103544                    NaN             NaN
# 103545                    NaN             NaN
#
# [5 rows x 145 columns]

# %%
df8.shape
# Out:
# (103546, 145)

# %%
df8.to_sql(name='LC_16-q4', con=engine, if_exists='replace', index = False)

# %%
SQL_STRING = '''

select * from "LC_16-q4"
'''

df = pd.read_sql(SQL_STRING, con=engine)
df.head()
# Out:
#      id member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  None      None      19200        19200          19200.0   36 months
# 1  None      None      11100        11100          11100.0   36 months
# 2  None      None       8000         8000           8000.0   36 months
# 3  None      None      39000        39000          39000.0   36 months
# 4  None      None      13400        13400          13400.0   36 months
#
#   int_rate  installment grade sub_grade       ...        \
# 0   13.99%       656.12     C        C3       ...
# 1    5.32%       334.28     A        A1       ...
# 2    7.99%       250.66     A        A5       ...
# 3   15.99%      1370.94     C        C5       ...
# 4   13.49%       454.67     C        C2       ...
#
#   hardship_payoff_balance_amount hardship_last_payment_amount  \
# 0                            NaN                          NaN
# 1                            NaN                          NaN
# 2                            NaN                          NaN
# 3                            NaN                          NaN
# 4                            NaN                          NaN
#
#   disbursement_method  debt_settlement_flag debt_settlement_flag_date  \
# 0                Cash                     N                      None
# 1                Cash                     N                      None
# 2                Cash                     N                      None
# 3                Cash                     N                      None
# 4                Cash                     N                      None
#
#   settlement_status settlement_date settlement_amount settlement_percentage  \
# 0              None            None               NaN                   NaN
# 1              None            None               NaN                   NaN
# 2              None            None               NaN                   NaN
# 3              None            None               NaN                   NaN
# 4              None            None               NaN                   NaN
#
#   settlement_term
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#
# [5 rows x 145 columns]

# %%
df.shape
# Out:
# (103546, 145)

# %% [markdown]
# ## 2017 Q1

# %%
file9 = './Datasets/Lending Club/lendclub_17-q1.csv'

# %%
df9 = pd.read_csv(file9, skiprows=1, skipfooter=2)
# Out:
# /Applications/anaconda2/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.

# %%
df9.head()
# Out:
#    id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0 NaN        NaN      15000        15000            15000   36 months
# 1 NaN        NaN      17000        17000            17000   36 months
# 2 NaN        NaN      20000        20000            20000   36 months
# 3 NaN        NaN      16000        16000            16000   60 months
# 4 NaN        NaN       2000         2000             2000   36 months
#
#   int_rate  installment grade sub_grade       ...         \
# 0    5.32%       451.73     A        A1       ...
# 1    7.49%       528.73     A        A4       ...
# 2    5.32%       602.30     A        A1       ...
# 3   12.74%       361.93     C        C1       ...
# 4   16.99%        71.30     D        D1       ...
#
#   hardship_payoff_balance_amount hardship_last_payment_amount  \
# 0                            NaN                          NaN
# 1                            NaN                          NaN
# 2                            NaN                          NaN
# 3                            NaN                          NaN
# 4                            NaN                          NaN
#
#   disbursement_method  debt_settlement_flag debt_settlement_flag_date  \
# 0                Cash                     N                       NaN
# 1                Cash                     N                       NaN
# 2                Cash                     N                       NaN
# 3                Cash                     N                       NaN
# 4                Cash                     N                       NaN
#
#   settlement_status settlement_date settlement_amount  settlement_percentage  \
# 0               NaN             NaN               NaN                    NaN
# 1               NaN             NaN               NaN                    NaN
# 2               NaN             NaN               NaN                    NaN
# 3               NaN             NaN               NaN                    NaN
# 4               NaN             NaN               NaN                    NaN
#
#    settlement_term
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
#
# [5 rows x 145 columns]

# %%
df9.tail()
# Out:
#        id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 96774 NaN        NaN      10400        10400            10400   36 months
# 96775 NaN        NaN      15000        15000            15000   36 months
# 96776 NaN        NaN      10000        10000            10000   36 months
# 96777 NaN        NaN       6325         6325             6325   36 months
# 96778 NaN        NaN      15625        15625            15625   60 months
#
#       int_rate  installment grade sub_grade       ...         \
# 96774   14.99%       360.47     C        C4       ...
# 96775   12.74%       503.54     C        C1       ...
# 96776    8.24%       314.48     B        B1       ...
# 96777   15.99%       222.34     C        C5       ...
# 96778   28.69%       493.03     F        F1       ...
#
#       hardship_payoff_balance_amount hardship_last_payment_amount  \
# 96774                            NaN                          NaN
# 96775                            NaN                          NaN
# 96776                            NaN                          NaN
# 96777                            NaN                          NaN
# 96778                            NaN                          NaN
#
#       disbursement_method  debt_settlement_flag debt_settlement_flag_date  \
# 96774                Cash                     N                       NaN
# 96775                Cash                     N                       NaN
# 96776                Cash                     N                       NaN
# 96777                Cash                     N                       NaN
# 96778                Cash                     N                       NaN
#
#       settlement_status settlement_date settlement_amount  \
# 96774               NaN             NaN               NaN
# 96775               NaN             NaN               NaN
# 96776               NaN             NaN               NaN
# 96777               NaN             NaN               NaN
# 96778               NaN             NaN               NaN
#
#        settlement_percentage  settlement_term
# 96774                    NaN              NaN
# 96775                    NaN              NaN
# 96776                    NaN              NaN
# 96777                    NaN              NaN
# 96778                    NaN              NaN
#
# [5 rows x 145 columns]

# %%
df9.shape
# Out:
# (96779, 145)

# %%
df9.to_sql(name='LC_17-q1', con=engine, if_exists='replace', index = False)

# %%
SQL_STRING = '''

select * from "LC_17-q1"
'''

df = pd.read_sql(SQL_STRING, con=engine)
df.head()
# Out:
#      id member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  None      None      15000        15000            15000   36 months
# 1  None      None      17000        17000            17000   36 months
# 2  None      None      20000        20000            20000   36 months
# 3  None      None      16000        16000            16000   60 months
# 4  None      None       2000         2000             2000   36 months
#
#   int_rate  installment grade sub_grade       ...        \
# 0    5.32%       451.73     A        A1       ...
# 1    7.49%       528.73     A        A4       ...
# 2    5.32%       602.30     A        A1       ...
# 3   12.74%       361.93     C        C1       ...
# 4   16.99%        71.30     D        D1       ...
#
#   hardship_payoff_balance_amount hardship_last_payment_amount  \
# 0                            NaN                          NaN
# 1                            NaN                          NaN
# 2                            NaN                          NaN
# 3                            NaN                          NaN
# 4                            NaN                          NaN
#
#   disbursement_method  debt_settlement_flag debt_settlement_flag_date  \
# 0                Cash                     N                      None
# 1                Cash                     N                      None
# 2                Cash                     N                      None
# 3                Cash                     N                      None
# 4                Cash                     N                      None
#
#   settlement_status settlement_date settlement_amount settlement_percentage  \
# 0              None            None               NaN                   NaN
# 1              None            None               NaN                   NaN
# 2              None            None               NaN                   NaN
# 3              None            None               NaN                   NaN
# 4              None            None               NaN                   NaN
#
#   settlement_term
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#
# [5 rows x 145 columns]

# %%
df.shape
# Out:
# (96779, 145)

# %% [markdown]
# ## 2017 Q2

# %%
file10 = './Datasets/Lending Club/lendclub_17-q2.csv'

# %%
df10 = pd.read_csv(file10, skiprows=1, skipfooter=2)
# Out:
# /Applications/anaconda2/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.

# %%
df10.head()
# Out:
#    id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0 NaN        NaN      12000        12000            12000   60 months
# 1 NaN        NaN       4000         4000             4000   36 months
# 2 NaN        NaN       6000         6000             6000   36 months
# 3 NaN        NaN      25000        25000            25000   60 months
# 4 NaN        NaN      10000        10000            10000   36 months
#
#   int_rate  installment grade sub_grade       ...         \
# 0   30.65%       393.05     F        F4       ...
# 1    5.32%       120.46     A        A1       ...
# 2    9.44%       192.03     B        B1       ...
# 3   15.05%       595.41     C        C4       ...
# 4    7.21%       309.74     A        A3       ...
#
#   hardship_payoff_balance_amount hardship_last_payment_amount  \
# 0                            NaN                          NaN
# 1                            NaN                          NaN
# 2                            NaN                          NaN
# 3                            NaN                          NaN
# 4                            NaN                          NaN
#
#   disbursement_method  debt_settlement_flag debt_settlement_flag_date  \
# 0                Cash                     N                       NaN
# 1                Cash                     N                       NaN
# 2                Cash                     N                       NaN
# 3                Cash                     N                       NaN
# 4                Cash                     N                       NaN
#
#   settlement_status settlement_date settlement_amount  settlement_percentage  \
# 0               NaN             NaN               NaN                    NaN
# 1               NaN             NaN               NaN                    NaN
# 2               NaN             NaN               NaN                    NaN
# 3               NaN             NaN               NaN                    NaN
# 4               NaN             NaN               NaN                    NaN
#
#    settlement_term
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
#
# [5 rows x 145 columns]

# %%
df10.tail()
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 105446 NaN        NaN      24000        24000            24000   60 months
# 105447 NaN        NaN      10000        10000            10000   36 months
# 105448 NaN        NaN      10050        10050            10050   36 months
# 105449 NaN        NaN       6000         6000             6000   36 months
# 105450 NaN        NaN      30000        30000            30000   60 months
#
#        int_rate  installment grade sub_grade       ...         \
# 105446   23.99%       690.30     E        E2       ...
# 105447    7.99%       313.32     A        A5       ...
# 105448   16.99%       358.26     D        D1       ...
# 105449   11.44%       197.69     B        B4       ...
# 105450   25.49%       889.18     E        E4       ...
#
#        hardship_payoff_balance_amount hardship_last_payment_amount  \
# 105446                            NaN                          NaN
# 105447                            NaN                          NaN
# 105448                            NaN                          NaN
# 105449                            NaN                          NaN
# 105450                            NaN                          NaN
#
#        disbursement_method  debt_settlement_flag debt_settlement_flag_date  \
# 105446                Cash                     N                       NaN
# 105447                Cash                     N                       NaN
# 105448                Cash                     N                       NaN
# 105449                Cash                     N                       NaN
# 105450                Cash                     N                       NaN
#
#        settlement_status settlement_date settlement_amount  \
# 105446               NaN             NaN               NaN
# 105447               NaN             NaN               NaN
# 105448               NaN             NaN               NaN
# 105449               NaN             NaN               NaN
# 105450               NaN             NaN               NaN
#
#         settlement_percentage  settlement_term
# 105446                    NaN              NaN
# 105447                    NaN              NaN
# 105448                    NaN              NaN
# 105449                    NaN              NaN
# 105450                    NaN              NaN
#
# [5 rows x 145 columns]

# %%
df10.shape
# Out:
# (105451, 145)

# %%
df10.to_sql(name='LC_17-q2', con=engine, if_exists='replace', index = False)

# %%
SQL_STRING = '''

select * from "LC_17-q2"
'''

df = pd.read_sql(SQL_STRING, con=engine)
df.head()
# Out:
#      id member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  None      None      12000        12000            12000   60 months
# 1  None      None       4000         4000             4000   36 months
# 2  None      None       6000         6000             6000   36 months
# 3  None      None      25000        25000            25000   60 months
# 4  None      None      10000        10000            10000   36 months
#
#   int_rate  installment grade sub_grade       ...        \
# 0   30.65%       393.05     F        F4       ...
# 1    5.32%       120.46     A        A1       ...
# 2    9.44%       192.03     B        B1       ...
# 3   15.05%       595.41     C        C4       ...
# 4    7.21%       309.74     A        A3       ...
#
#   hardship_payoff_balance_amount hardship_last_payment_amount  \
# 0                            NaN                          NaN
# 1                            NaN                          NaN
# 2                            NaN                          NaN
# 3                            NaN                          NaN
# 4                            NaN                          NaN
#
#   disbursement_method  debt_settlement_flag debt_settlement_flag_date  \
# 0                Cash                     N                      None
# 1                Cash                     N                      None
# 2                Cash                     N                      None
# 3                Cash                     N                      None
# 4                Cash                     N                      None
#
#   settlement_status settlement_date settlement_amount settlement_percentage  \
# 0              None            None               NaN                   NaN
# 1              None            None               NaN                   NaN
# 2              None            None               NaN                   NaN
# 3              None            None               NaN                   NaN
# 4              None            None               NaN                   NaN
#
#   settlement_term
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#
# [5 rows x 145 columns]

# %%
df.shape
# Out:
# (105451, 145)

# %% [markdown]
# ## 2017 Q3

# %%
file11 = './Datasets/Lending Club/lendclub_17-q3.csv'

# %%
df11 = pd.read_csv(file11, skiprows=1, skipfooter=2)
# Out:
# /Applications/anaconda2/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.

# %%
df11.head()
# Out:
#    id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0 NaN        NaN       7000         7000             7000   36 months
# 1 NaN        NaN      12000        12000            12000   36 months
# 2 NaN        NaN      16000        16000            16000   36 months
# 3 NaN        NaN      32000        32000            32000   36 months
# 4 NaN        NaN      33000        33000            33000   36 months
#
#   int_rate  installment grade sub_grade       ...         \
# 0    7.97%       219.26     A        A5       ...
# 1    7.97%       375.88     A        A5       ...
# 2    7.97%       501.17     A        A5       ...
# 3   11.99%      1062.71     B        B5       ...
# 4    7.21%      1022.12     A        A3       ...
#
#   hardship_payoff_balance_amount hardship_last_payment_amount  \
# 0                            NaN                          NaN
# 1                            NaN                          NaN
# 2                            NaN                          NaN
# 3                            NaN                          NaN
# 4                            NaN                          NaN
#
#   disbursement_method  debt_settlement_flag debt_settlement_flag_date  \
# 0                Cash                     N                       NaN
# 1                Cash                     N                       NaN
# 2                Cash                     N                       NaN
# 3                Cash                     N                       NaN
# 4                Cash                     N                       NaN
#
#   settlement_status settlement_date settlement_amount  settlement_percentage  \
# 0               NaN             NaN               NaN                    NaN
# 1               NaN             NaN               NaN                    NaN
# 2               NaN             NaN               NaN                    NaN
# 3               NaN             NaN               NaN                    NaN
# 4               NaN             NaN               NaN                    NaN
#
#    settlement_term
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
#
# [5 rows x 145 columns]

# %%
df11.tail()
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 122696 NaN        NaN       6000         6000             6000   36 months
# 122697 NaN        NaN      20000        20000            20000   60 months
# 122698 NaN        NaN      35000        35000            35000   60 months
# 122699 NaN        NaN      30775        30775            30525   60 months
# 122700 NaN        NaN      18900        18900            18900   60 months
#
#        int_rate  installment grade sub_grade       ...         \
# 122696   23.88%       235.02     E        E2       ...
# 122697   26.30%       602.37     E        E5       ...
# 122698   30.89%      1151.58     G        G3       ...
# 122699   30.65%      1008.00     F        F4       ...
# 122700   30.94%       622.44     G        G4       ...
#
#        hardship_payoff_balance_amount hardship_last_payment_amount  \
# 122696                            NaN                          NaN
# 122697                            NaN                          NaN
# 122698                            NaN                          NaN
# 122699                            NaN                          NaN
# 122700                            NaN                          NaN
#
#        disbursement_method  debt_settlement_flag debt_settlement_flag_date  \
# 122696                Cash                     N                       NaN
# 122697                Cash                     N                       NaN
# 122698                Cash                     N                       NaN
# 122699                Cash                     N                       NaN
# 122700                Cash                     N                       NaN
#
#        settlement_status settlement_date settlement_amount  \
# 122696               NaN             NaN               NaN
# 122697               NaN             NaN               NaN
# 122698               NaN             NaN               NaN
# 122699               NaN             NaN               NaN
# 122700               NaN             NaN               NaN
#
#         settlement_percentage  settlement_term
# 122696                    NaN              NaN
# 122697                    NaN              NaN
# 122698                    NaN              NaN
# 122699                    NaN              NaN
# 122700                    NaN              NaN
#
# [5 rows x 145 columns]

# %%
df11.shape
# Out:
# (122701, 145)

# %%
df11.to_sql(name='LC_17-q3', con=engine, if_exists='replace', index = False)

# %%
SQL_STRING = '''

select * from "LC_17-q3"
'''

df = pd.read_sql(SQL_STRING, con=engine)
df.head()
# Out:
#      id member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  None      None       7000         7000             7000   36 months
# 1  None      None      12000        12000            12000   36 months
# 2  None      None      16000        16000            16000   36 months
# 3  None      None      32000        32000            32000   36 months
# 4  None      None      33000        33000            33000   36 months
#
#   int_rate  installment grade sub_grade       ...        \
# 0    7.97%       219.26     A        A5       ...
# 1    7.97%       375.88     A        A5       ...
# 2    7.97%       501.17     A        A5       ...
# 3   11.99%      1062.71     B        B5       ...
# 4    7.21%      1022.12     A        A3       ...
#
#   hardship_payoff_balance_amount hardship_last_payment_amount  \
# 0                            NaN                          NaN
# 1                            NaN                          NaN
# 2                            NaN                          NaN
# 3                            NaN                          NaN
# 4                            NaN                          NaN
#
#   disbursement_method  debt_settlement_flag debt_settlement_flag_date  \
# 0                Cash                     N                      None
# 1                Cash                     N                      None
# 2                Cash                     N                      None
# 3                Cash                     N                      None
# 4                Cash                     N                      None
#
#   settlement_status settlement_date settlement_amount settlement_percentage  \
# 0              None            None               NaN                   NaN
# 1              None            None               NaN                   NaN
# 2              None            None               NaN                   NaN
# 3              None            None               NaN                   NaN
# 4              None            None               NaN                   NaN
#
#   settlement_term
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#
# [5 rows x 145 columns]

# %%
df.shape
# Out:
# (122701, 145)

# %% [markdown]
# ## 2017 Q4

# %%
file12 = './Datasets/Lending Club/lendclub_17-q4.csv'

# %%
df12 = pd.read_csv(file12, skiprows=1, skipfooter=2)
# Out:
# /Applications/anaconda2/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.

# %%
df12.head()
# Out:
#    id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0 NaN        NaN      35000        35000          35000.0   60 months
# 1 NaN        NaN       6000         6000           6000.0   36 months
# 2 NaN        NaN      40000        40000          40000.0   36 months
# 3 NaN        NaN      10000        10000          10000.0   60 months
# 4 NaN        NaN      27000        27000          27000.0   60 months
#
#   int_rate  installment grade sub_grade       ...         \
# 0   11.99%       778.38     B        B5       ...
# 1    7.35%       186.23     A        A4       ...
# 2    6.08%      1218.33     A        A2       ...
# 3   23.88%       286.99     E        E2       ...
# 4    9.93%       572.75     B        B2       ...
#
#   hardship_payoff_balance_amount hardship_last_payment_amount  \
# 0                            NaN                          NaN
# 1                            NaN                          NaN
# 2                            NaN                          NaN
# 3                            NaN                          NaN
# 4                            NaN                          NaN
#
#   disbursement_method  debt_settlement_flag debt_settlement_flag_date  \
# 0                Cash                     N                       NaN
# 1                Cash                     N                       NaN
# 2                Cash                     N                       NaN
# 3                Cash                     N                       NaN
# 4                Cash                     N                       NaN
#
#   settlement_status settlement_date settlement_amount  settlement_percentage  \
# 0               NaN             NaN               NaN                    NaN
# 1               NaN             NaN               NaN                    NaN
# 2               NaN             NaN               NaN                    NaN
# 3               NaN             NaN               NaN                    NaN
# 4               NaN             NaN               NaN                    NaN
#
#    settlement_term
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
#
# [5 rows x 145 columns]

# %%
df12.tail()
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 118643 NaN        NaN      12000        12000          12000.0   60 months
# 118644 NaN        NaN      12000        12000          12000.0   60 months
# 118645 NaN        NaN      10000        10000          10000.0   36 months
# 118646 NaN        NaN      12000        12000          12000.0   60 months
# 118647 NaN        NaN      16550        16550          16550.0   60 months
#
#        int_rate  installment grade sub_grade       ...         \
# 118643   14.08%       279.72     C        C3       ...
# 118644   25.82%       358.01     E        E4       ...
# 118645   11.99%       332.10     B        B5       ...
# 118646   21.45%       327.69     D        D5       ...
# 118647   21.45%       451.94     D        D5       ...
#
#        hardship_payoff_balance_amount hardship_last_payment_amount  \
# 118643                            NaN                          NaN
# 118644                            NaN                          NaN
# 118645                            NaN                          NaN
# 118646                            NaN                          NaN
# 118647                            NaN                          NaN
#
#        disbursement_method  debt_settlement_flag debt_settlement_flag_date  \
# 118643                Cash                     N                       NaN
# 118644                Cash                     N                       NaN
# 118645                Cash                     N                       NaN
# 118646                Cash                     N                       NaN
# 118647                Cash                     N                       NaN
#
#        settlement_status settlement_date settlement_amount  \
# 118643               NaN             NaN               NaN
# 118644               NaN             NaN               NaN
# 118645               NaN             NaN               NaN
# 118646               NaN             NaN               NaN
# 118647               NaN             NaN               NaN
#
#         settlement_percentage  settlement_term
# 118643                    NaN              NaN
# 118644                    NaN              NaN
# 118645                    NaN              NaN
# 118646                    NaN              NaN
# 118647                    NaN              NaN
#
# [5 rows x 145 columns]

# %%
df12.shape
# Out:
# (118648, 145)

# %%
df12.to_sql(name='LC_17-q4', con=engine, if_exists='replace', index = False)

# %%
SQL_STRING = '''

select * from "LC_17-q4"
'''

df = pd.read_sql(SQL_STRING, con=engine)
df.head()
# Out:
#      id member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  None      None      35000        35000          35000.0   60 months
# 1  None      None       6000         6000           6000.0   36 months
# 2  None      None      40000        40000          40000.0   36 months
# 3  None      None      10000        10000          10000.0   60 months
# 4  None      None      27000        27000          27000.0   60 months
#
#   int_rate  installment grade sub_grade       ...        \
# 0   11.99%       778.38     B        B5       ...
# 1    7.35%       186.23     A        A4       ...
# 2    6.08%      1218.33     A        A2       ...
# 3   23.88%       286.99     E        E2       ...
# 4    9.93%       572.75     B        B2       ...
#
#   hardship_payoff_balance_amount hardship_last_payment_amount  \
# 0                            NaN                          NaN
# 1                            NaN                          NaN
# 2                            NaN                          NaN
# 3                            NaN                          NaN
# 4                            NaN                          NaN
#
#   disbursement_method  debt_settlement_flag debt_settlement_flag_date  \
# 0                Cash                     N                      None
# 1                Cash                     N                      None
# 2                Cash                     N                      None
# 3                Cash                     N                      None
# 4                Cash                     N                      None
#
#   settlement_status settlement_date settlement_amount settlement_percentage  \
# 0              None            None               NaN                   NaN
# 1              None            None               NaN                   NaN
# 2              None            None               NaN                   NaN
# 3              None            None               NaN                   NaN
# 4              None            None               NaN                   NaN
#
#   settlement_term
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#
# [5 rows x 145 columns]

# %%
df.shape
# Out:
# (118648, 145)

# %% [markdown]
# ---
# All 12 csv files are now in SQL tables. I can sum the lengths of the dataframes to check how large the table would be if I concatonated them all into one large table.
#
# ---

# %%
shape = ((df1.shape[0] + df2.shape[0] + df3.shape[0] + df4.shape[0] + df5.shape[0] + df6.shape[0] + df7.shape[0] + df8.shape[0] + df9.shape[0] + df10.shape[0] + df11.shape[0] +df12.shape[0]), df.shape[1])

# %%
print(shape)
# Out:
# (1765427, 145)

# %% [markdown]
# ---
# The total size would be nearly 1.8 million rows.
#
# ---

# %%
# Test an SQL query
SQL_STRING = '''

select loan_status from "LC_16-q2"
'''

df = pd.read_sql(SQL_STRING, con=engine)
df.head()
# Out:
#    loan_status
# 0      Current
# 1  Charged Off
# 2      Current
# 3      Current
# 4   Fully Paid

# %% [markdown]
# ## Concatonation

# %% [markdown]
# ---
# I have now pushed all 12 csv files into SQL tables. Now I need to vertically concatonate them to form one large table and then push that into a new SQL table.

# %% [markdown]
# First read in all 12 sql tables:
#
# ---

# %%
# (2007-11)
SQL_STRING = '''

select * from "LC_07-11"

'''

lc1 = pd.read_sql(SQL_STRING, con=engine)
lc1.shape
# Out:
# (42536, 145)

# %%
# (2012-13)
SQL_STRING = '''

select * from "LC_12-13"

'''

lc2 = pd.read_sql(SQL_STRING, con=engine)
lc2.shape
# Out:
# (188181, 145)

# %%
# (2014)
SQL_STRING = '''

select * from "LC_14"

'''

lc3 = pd.read_sql(SQL_STRING, con=engine)
lc3.shape
# Out:
# (235629, 145)

# %%
# (2015)
SQL_STRING = '''

select * from "LC_15"

'''

lc4 = pd.read_sql(SQL_STRING, con=engine)
lc4.shape
# Out:
# (421095, 145)

# %%
# (2016-Q1)
SQL_STRING = '''

select * from "LC_16-q1"

'''

lc5 = pd.read_sql(SQL_STRING, con=engine)
lc5.shape
# Out:
# (133887, 145)

# %%
# (2016-Q2)
SQL_STRING = '''

select * from "LC_16-q2"

'''

lc6 = pd.read_sql(SQL_STRING, con=engine)
lc6.shape
# Out:
# (97854, 145)

# %%
# (2016-Q3)
SQL_STRING = '''

select * from "LC_16-q3"

'''

lc7 = pd.read_sql(SQL_STRING, con=engine)
lc7.shape
# Out:
# (99120, 145)

# %%
# (2016-Q4)
SQL_STRING = '''

select * from "LC_16-q4"

'''

lc8 = pd.read_sql(SQL_STRING, con=engine)
lc8.shape
# Out:
# (103546, 145)

# %%
# (2017-Q1)
SQL_STRING = '''

select * from "LC_17-q1"

'''

lc9 = pd.read_sql(SQL_STRING, con=engine)
lc9.shape
# Out:
# (96779, 145)

# %%
# (2017-Q2)
SQL_STRING = '''

select * from "LC_17-q2"

'''

lc10 = pd.read_sql(SQL_STRING, con=engine)
lc10.shape
# Out:
# (105451, 145)

# %%
# (2017-Q3)
SQL_STRING = '''

select * from "LC_17-q3"

'''

lc11 = pd.read_sql(SQL_STRING, con=engine)
lc11.shape
# Out:
# (122701, 145)

# %%
# (2017-Q4)
SQL_STRING = '''

select * from "LC_17-q4"

'''

lc12 = pd.read_sql(SQL_STRING, con=engine)
lc12.shape
# Out:
# (118648, 145)

# %% [markdown]
# ---
# Now that I have read all tables into pandas, I need to vertically concatonate them to form 1 large dataframe.
#
# ---

# %%
df = pd.concat([lc1, lc2], axis=0)
df.shape
# Out:
# (230717, 145)

# %%
df = pd.concat([df, lc3], axis=0)
df.shape
# Out:
# (466346, 145)

# %%
df = pd.concat([df, lc4], axis=0)
df.shape
# Out:
# (887441, 145)

# %%
df = pd.concat([df, lc5], axis=0)
df.shape
# Out:
# (1021328, 145)

# %%
df = pd.concat([df, lc6], axis=0)
df.shape
# Out:
# (1119182, 145)

# %%
df = pd.concat([df, lc7], axis=0)
df.shape
# Out:
# (1218302, 145)

# %%
df = pd.concat([df, lc8], axis=0)
df.shape
# Out:
# (1321848, 145)

# %%
df = pd.concat([df, lc9], axis=0)
df.shape
# Out:
# (1418627, 145)

# %%
df = pd.concat([df, lc10], axis=0)
df.shape
# Out:
# (1524078, 145)

# %%
df = pd.concat([df, lc11], axis=0)
df.shape
# Out:
# (1646779, 145)

# %%
df = pd.concat([df, lc12], axis=0)
df.shape
# Out:
# (1765427, 145)

# %% [markdown]
# ---
# As the id column is empty, I will set it to be the index +1 (+1 because the index starts at 0). That way I will have a unique id for each record in case I need one.
#
# ---

# %%
df.id = df.index+1

# %%
df.head(50)
# Out:
#     id member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0    1      None     5000.0       5000.0      4975.000000   36 months
# 1    2      None     2500.0       2500.0      2500.000000   60 months
# 2    3      None     2400.0       2400.0      2400.000000   36 months
# 3    4      None    10000.0      10000.0     10000.000000   36 months
# 4    5      None     3000.0       3000.0      3000.000000   60 months
# 5    6      None     5000.0       5000.0      5000.000000   36 months
# 6    7      None     7000.0       7000.0      7000.000000   60 months
# 7    8      None     3000.0       3000.0      3000.000000   36 months
# 8    9      None     5600.0       5600.0      5600.000000   60 months
# 9   10      None     5375.0       5375.0      5350.000000   60 months
# 10  11      None    21000.0      21000.0     21000.000000   36 months
# 11  12      None     6500.0       6500.0      6500.000000   60 months
# 12  13      None    12000.0      12000.0     12000.000000   36 months
# 13  14      None     9000.0       9000.0      9000.000000   36 months
# 14  15      None     3000.0       3000.0      3000.000000   36 months
# 15  16      None    10000.0      10000.0     10000.000000   36 months
# 16  17      None     1000.0       1000.0      1000.000000   36 months
# 17  18      None    10000.0      10000.0     10000.000000   36 months
# 18  19      None     3600.0       3600.0      3600.000000   36 months
# 19  20      None     6000.0       6000.0      6000.000000   36 months
# 20  21      None     9200.0       9200.0      9200.000000   36 months
# 21  22      None    20250.0      20250.0     19142.161077   60 months
# 22  23      None    10000.0      10000.0     10000.000000   36 months
# 23  24      None    10000.0      10000.0     10000.000000   36 months
# 24  25      None     6000.0       6000.0      6000.000000   36 months
# 25  26      None    15000.0      15000.0     15000.000000   36 months
# 26  27      None    15000.0      15000.0      8725.000000   36 months
# 27  28      None     5000.0       5000.0      5000.000000   60 months
# 28  29      None     4000.0       4000.0      4000.000000   36 months
# 29  30      None     8500.0       8500.0      8500.000000   36 months
# 30  31      None     4375.0       4375.0      4375.000000   36 months
# 31  32      None    31825.0      31825.0     31825.000000   36 months
# 32  33      None    10000.0      10000.0      9975.000000   60 months
# 33  34      None     5000.0       5000.0      5000.000000   36 months
# 34  35      None     7000.0       7000.0      7000.000000   36 months
# 35  36      None    12400.0      12400.0     12400.000000   36 months
# 36  37      None    10800.0      10800.0     10800.000000   36 months
# 37  38      None    15000.0      15000.0     15000.000000   36 months
# 38  39      None     6000.0       6000.0      6000.000000   36 months
# 39  40      None    12500.0      12500.0     12475.000000   60 months
# 40  41      None     9600.0       9600.0      9600.000000   36 months
# 41  42      None    12000.0      12000.0     12000.000000   36 months
# 42  43      None     3000.0       3000.0      3000.000000   36 months
# 43  44      None     4400.0       4400.0      4400.000000   36 months
# 44  45      None     6000.0       6000.0      6000.000000   36 months
# 45  46      None    14000.0      14000.0     14000.000000   36 months
# 46  47      None     5000.0       5000.0      5000.000000   36 months
# 47  48      None    10000.0      10000.0     10000.000000   36 months
# 48  49      None    10000.0      10000.0     10000.000000   36 months
# 49  50      None    11000.0      11000.0     11000.000000   36 months
#
#    int_rate  installment grade sub_grade       ...        \
# 0    10.65%       162.87     B        B2       ...
# 1    15.27%        59.83     C        C4       ...
# 2    15.96%        84.33     C        C5       ...
# 3    13.49%       339.31     C        C1       ...
# 4    12.69%        67.79     B        B5       ...
# 5     7.90%       156.46     A        A4       ...
# 6    15.96%       170.08     C        C5       ...
# 7    18.64%       109.43     E        E1       ...
# 8    21.28%       152.39     F        F2       ...
# 9    12.69%       121.45     B        B5       ...
# 10   12.42%       701.73     B        B4       ...
# 11   14.65%       153.45     C        C3       ...
# 12   12.69%       402.54     B        B5       ...
# 13   13.49%       305.38     C        C1       ...
# 14    9.91%        96.68     B        B1       ...
# 15   10.65%       325.74     B        B2       ...
# 16   16.29%        35.31     D        D1       ...
# 17   15.27%       347.98     C        C4       ...
# 18    6.03%       109.57     A        A1       ...
# 19   11.71%       198.46     B        B3       ...
# 20    6.03%       280.01     A        A1       ...
# 21   15.27%       484.63     C        C4       ...
# 22   11.71%       330.76     B        B3       ...
# 23   11.71%       330.76     B        B3       ...
# 24   11.71%       198.46     B        B3       ...
# 25    9.91%       483.38     B        B1       ...
# 26   14.27%       514.64     C        C2       ...
# 27   16.77%       123.65     D        D2       ...
# 28   11.71%       132.31     B        B3       ...
# 29   11.71%       281.15     B        B3       ...
# 30    7.51%       136.11     A        A3       ...
# 31    7.90%       995.82     A        A4       ...
# 32   15.96%       242.97     C        C5       ...
# 33    8.90%       158.77     A        A5       ...
# 34   15.96%       245.97     C        C5       ...
# 35   10.65%       403.91     B        B2       ...
# 36    9.91%       348.03     B        B1       ...
# 37    7.90%       469.36     A        A4       ...
# 38   12.42%       200.50     B        B4       ...
# 39   12.69%       282.44     B        B5       ...
# 40    7.51%       298.67     A        A3       ...
# 41    7.90%       375.49     A        A4       ...
# 42   18.25%       108.84     D        D5       ...
# 43   16.77%       156.37     D        D2       ...
# 44    6.03%       182.62     A        A1       ...
# 45    9.91%       451.15     B        B1       ...
# 46    8.90%       158.77     A        A5       ...
# 47   10.65%       325.74     B        B2       ...
# 48    6.03%       304.36     A        A1       ...
# 49    6.62%       337.75     A        A2       ...
#
#    hardship_payoff_balance_amount hardship_last_payment_amount  \
# 0                            None                         None
# 1                            None                         None
# 2                            None                         None
# 3                            None                         None
# 4                            None                         None
# 5                            None                         None
# 6                            None                         None
# 7                            None                         None
# 8                            None                         None
# 9                            None                         None
# 10                           None                         None
# 11                           None                         None
# 12                           None                         None
# 13                           None                         None
# 14                           None                         None
# 15                           None                         None
# 16                           None                         None
# 17                           None                         None
# 18                           None                         None
# 19                           None                         None
# 20                           None                         None
# 21                           None                         None
# 22                           None                         None
# 23                           None                         None
# 24                           None                         None
# 25                           None                         None
# 26                           None                         None
# 27                           None                         None
# 28                           None                         None
# 29                           None                         None
# 30                           None                         None
# 31                           None                         None
# 32                           None                         None
# 33                           None                         None
# 34                           None                         None
# 35                           None                         None
# 36                           None                         None
# 37                           None                         None
# 38                           None                         None
# 39                           None                         None
# 40                           None                         None
# 41                           None                         None
# 42                           None                         None
# 43                           None                         None
# 44                           None                         None
# 45                           None                         None
# 46                           None                         None
# 47                           None                         None
# 48                           None                         None
# 49                           None                         None
#
#    disbursement_method  debt_settlement_flag debt_settlement_flag_date  \
# 0                 Cash                     N                      None
# 1                 Cash                     N                      None
# 2                 Cash                     N                      None
# 3                 Cash                     N                      None
# 4                 Cash                     N                      None
# 5                 Cash                     N                      None
# 6                 Cash                     N                      None
# 7                 Cash                     N                      None
# 8                 Cash                     N                      None
# 9                 Cash                     N                      None
# 10                Cash                     N                      None
# 11                Cash                     N                      None
# 12                Cash                     N                      None
# 13                Cash                     N                      None
# 14                Cash                     N                      None
# 15                Cash                     N                      None
# 16                Cash                     N                      None
# 17                Cash                     N                      None
# 18                Cash                     N                      None
# 19                Cash                     N                      None
# 20                Cash                     N                      None
# 21                Cash                     N                      None
# 22                Cash                     N                      None
# 23                Cash                     N                      None
# 24                Cash                     N                      None
# 25                Cash                     N                      None
# 26                Cash                     N                      None
# 27                Cash                     N                      None
# 28                Cash                     N                      None
# 29                Cash                     N                      None
# 30                Cash                     N                      None
# 31                Cash                     N                      None
# 32                Cash                     N                      None
# 33                Cash                     N                      None
# 34                Cash                     N                      None
# 35                Cash                     N                      None
# 36                Cash                     N                      None
# 37                Cash                     N                      None
# 38                Cash                     N                      None
# 39                Cash                     N                      None
# 40                Cash                     N                      None
# 41                Cash                     N                      None
# 42                Cash                     N                      None
# 43                Cash                     N                      None
# 44                Cash                     N                      None
# 45                Cash                     N                      None
# 46                Cash                     N                      None
# 47                Cash                     N                      None
# 48                Cash                     N                      None
# 49                Cash                     N                      None
#
#    settlement_status settlement_date settlement_amount settlement_percentage  \
# 0               None            None               NaN                   NaN
# 1               None            None               NaN                   NaN
# 2               None            None               NaN                   NaN
# 3               None            None               NaN                   NaN
# 4               None            None               NaN                   NaN
# 5               None            None               NaN                   NaN
# 6               None            None               NaN                   NaN
# 7               None            None               NaN                   NaN
# 8               None            None               NaN                   NaN
# 9               None            None               NaN                   NaN
# 10              None            None               NaN                   NaN
# 11              None            None               NaN                   NaN
# 12              None            None               NaN                   NaN
# 13              None            None               NaN                   NaN
# 14              None            None               NaN                   NaN
# 15              None            None               NaN                   NaN
# 16              None            None               NaN                   NaN
# 17              None            None               NaN                   NaN
# 18              None            None               NaN                   NaN
# 19              None            None               NaN                   NaN
# 20              None            None               NaN                   NaN
# 21              None            None               NaN                   NaN
# 22              None            None               NaN                   NaN
# 23              None            None               NaN                   NaN
# 24              None            None               NaN                   NaN
# 25              None            None               NaN                   NaN
# 26              None            None               NaN                   NaN
# 27              None            None               NaN                   NaN
# 28              None            None               NaN                   NaN
# 29              None            None               NaN                   NaN
# 30              None            None               NaN                   NaN
# 31              None            None               NaN                   NaN
# 32              None            None               NaN                   NaN
# 33              None            None               NaN                   NaN
# 34              None            None               NaN                   NaN
# 35              None            None               NaN                   NaN
# 36              None            None               NaN                   NaN
# 37              None            None               NaN                   NaN
# 38              None            None               NaN                   NaN
# 39              None            None               NaN                   NaN
# 40              None            None               NaN                   NaN
# 41              None            None               NaN                   NaN
# 42              None            None               NaN                   NaN
# 43              None            None               NaN                   NaN
# 44              None            None               NaN                   NaN
# 45              None            None               NaN                   NaN
# 46              None            None               NaN                   NaN
# 47              None            None               NaN                   NaN
# 48              None            None               NaN                   NaN
# 49              None            None               NaN                   NaN
#
#    settlement_term
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# 5              NaN
# 6              NaN
# 7              NaN
# 8              NaN
# 9              NaN
# 10             NaN
# 11             NaN
# 12             NaN
# 13             NaN
# 14             NaN
# 15             NaN
# 16             NaN
# 17             NaN
# 18             NaN
# 19             NaN
# 20             NaN
# 21             NaN
# 22             NaN
# 23             NaN
# 24             NaN
# 25             NaN
# 26             NaN
# 27             NaN
# 28             NaN
# 29             NaN
# 30             NaN
# 31             NaN
# 32             NaN
# 33             NaN
# 34             NaN
# 35             NaN
# 36             NaN
# 37             NaN
# 38             NaN
# 39             NaN
# 40             NaN
# 41             NaN
# 42             NaN
# 43             NaN
# 44             NaN
# 45             NaN
# 46             NaN
# 47             NaN
# 48             NaN
# 49             NaN
#
# [50 rows x 145 columns]

# %% [markdown]
# ---
# I can now push the full dataframe into a new SQL table.
#
# ---

# %%
df.to_sql(name='Lending Club', con=engine, if_exists='replace', index = False)
